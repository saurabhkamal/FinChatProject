# %% [markdown]
# # ✅ **30 Questions You Can Ask From This Financial Document (Alphabet 10-K)**
#
# ### **Business Model & Strategy**
#
# 1. What are Alphabet’s main business segments and how are they structured?
# 2. What is Google’s mission and how has it evolved since the company was founded?
# 3. What is the role of AI in Alphabet’s overall business strategy?
# 4. How is the Gemini model being integrated across Alphabet’s products?
# 5. How does Alphabet define and approach moonshot projects?
#
# ### **Products & Services**
#
# 6. How does Alphabet generate most of its revenue from Google Services?
# 7. What is the difference between performance advertising and brand advertising in Google’s ecosystem?
# 8. How does Google Cloud generate revenue? (subscription vs consumption)
# 9. What types of AI services does Google Cloud offer to developers and enterprises?
# 10. What are the key products under Other Bets, and how do they generate revenue?
#
# ### **Competition**
#
# 11. Who are Alphabet’s biggest competitors across search, cloud, AI, hardware, and digital content?
# 12. How does Alphabet plan to remain competitive in the rapidly evolving AI landscape?
# 13. What competitive risks does Alphabet face in advertising due to new technologies and regulation?
#
# ### **Financial Performance & Risks**
#
# 14. How much of Alphabet’s revenue in 2024 came from advertising?
# 15. What macroeconomic conditions could negatively impact Google’s advertising business?
# 16. What factors may cause Alphabet’s operating margins to decline in the future?
# 17. Why might Alphabet’s revenue growth rate decline over time?
# 18. What risks does Alphabet face in terms of foreign currency exchange fluctuations?
#
# ### **AI-Specific Risks**
#
# 19. What risks does Alphabet associate with the development and deployment of AI technologies?
# 20. How could misuse or errors in AI systems create reputational or legal challenges for Alphabet?
# 21. What steps does Alphabet take to build safe and responsible AI?
#
# ### **Privacy, Security & Regulation**
#
# 22. What cybersecurity threats could disrupt Alphabet’s operations or data centers?
# 23. What privacy and data protection challenges does Alphabet highlight as risks?
# 24. How do global regulatory pressures affect Google’s operations (competition, content moderation, AI, data privacy)?
# 25. What risks arise from third parties misusing user data on Google’s platforms?
#
# ### **Sustainability & ESG**
#
# 26. What are Alphabet’s sustainability goals for 2030, including emissions and carbon-free energy?
# 27. What environmental risks could affect Alphabet’s data centers and supply chain?
#
# ### **Supply Chain & Operations**
#
# 28. What supply chain disruptions could affect Google’s ability to manufacture devices or operate data centers?
# 29. Why is Alphabet concerned about securing enough AI accelerator hardware (TPUs/GPUs)?
# 30. How does reliance on third-party suppliers and contract manufacturers pose operational risks for Alphabet?
#
# ---

# %% [markdown]
# * **Alphabet (Google)**
# * **Walmart** (exhibits & filings referenced)
# * **JPMorgan Chase & Co.**
# * **BlackRock, Inc.**
# * **Tesla, Inc.**
#
#
# ---
#
# # ✅ **30 Questions for Alphabet (Google)**
#
# (You already received ~30 earlier — here are 20 more new ones)
#
# 1. What are Alphabet’s main long-term financial trends?
# 2. How does Alphabet expect AI integration to affect its monetization strategy?
# 3. How does Alphabet expect TAC (traffic acquisition costs) to evolve?
# 4. How do user behavior changes influence Alphabet’s advertising revenue?
# 5. Why does Alphabet expect margin pressure in the coming years?
# 6. How do global smartphone trends affect Alphabet’s mobile ad revenue?
# 7. How does Alphabet anticipate international markets contributing to future growth?
# 8. How do foreign currency movements affect Alphabet’s financial performance?
# 9. What regulatory areas does Alphabet identify as fast-changing? (AI, content moderation, privacy)
# 10. In which countries does Alphabet face labor representation obligations?
# 11. How does Alphabet manage staffing through external vendors and contractors?
# 12. What new AI laws and regulations may affect Alphabet’s business model?
# 13. What risks come from inconsistent global laws on content moderation?
# 14. How does Alphabet protect its intellectual property portfolio?
# 15. What are Alphabet’s major trademark and patent strategies?
# 16. What sustainability information does Alphabet disclose primarily online?
# 17. How does Alphabet view macroeconomic risk in advertising demand?
# 18. How does Alphabet measure advertising value for partners?
# 19. What risks arise from third-party cookie policy changes?
# 20. How does Alphabet evaluate new product categories before monetizing them?
#
# ---
#
# # ✅ **30 Questions for JPMorgan Chase & Co.**
#
# (based on the JPM 2024 10-K sections in your PDF)
#
# 1. What are JPMorgan’s three reportable business segments?
# 2. What caused JPMorgan to reorganize its business segments in 2024?
# 3. How does the consumer segment differ from the wholesale segment?
# 4. What was the impact of the First Republic Bank acquisition?
# 5. How does JPMorgan define segment performance metrics in its MD&A?
# 6. What were JPMorgan’s non-interest revenue trends for 2024 vs. 2023?
# 7. What drove increases in JPMorgan’s net interest income in 2024?
# 8. What regulatory capital constraints does JPMorgan highlight?
# 9. What risks arise from off-balance-sheet lending commitments?
# 10. What litigation categories does JPMorgan disclose?
# 11. What changes were made in ASU 2023-07 affecting segment reporting?
# 12. How do new tax disclosure requirements (ASU 2023-09) affect JPMorgan?
# 13. How does ASU 2024-03 impact expense disaggregation?
# 14. What are JPMorgan’s defined benefit obligations across regions?
# 15. What portion of JPM’s revenue comes from related-party investment advisory fees?
# 16. What are JPMorgan’s restrictions on intercompany cash transfers?
# 17. How does JPMorgan define business thresholds for lines of business?
# 18. How does JPMorgan evaluate performance ranking for incentive compensation?
# 19. What are the major categories in JPM’s MD&A overview?
# 20. What does JPMorgan disclose about international operations?
# 21. How does JPMorgan manage registered investment company relationships?
# 22. How do macroeconomic trends influence JPMorgan’s loan loss provisions?
# 23. What is JPMorgan’s approach to cybersecurity as disclosed? (in 10-K)
# 24. What revenue drivers differ across CCB, CIB, and AWM segments?
# 25. What regulatory websites does JPMorgan use for investor disclosures?
# 26. What are key risks highlighted in the risk factor section?
# 27. How does JPMorgan describe its capital adequacy framework?
# 28. What were JPMorgan’s key drivers of YoY change in net income?
# 29. How did First Republic integration affect JPMorgan’s cost structure?
# 30. What glossary or technical terms does JPMorgan include in the 10-K?
#
# ---
#
# # ✅ **30 Questions for Tesla, Inc.**
#
# (found in the Tesla 2023 10-K sections)
#
# 1. What is Tesla’s primary source of revenue, and how has it evolved?
# 2. What operational risks does Tesla identify in the supply chain?
# 3. How does Tesla describe its production capacity expansion plans?
# 4. What competitive pressures does Tesla face in the EV market?
# 5. What risks arise from global regulatory scrutiny on energy storage or autonomy?
# 6. How does Tesla approach cybersecurity risk disclosures?
# 7. What market risk disclosures does Tesla provide in Item 7A?
# 8. What legal proceedings affect Tesla in Item 3?
# 9. What assumptions underpin Tesla’s forward-looking statements?
# 10. How does Tesla evaluate demand for its technologies?
# 11. What uncertainties affect Tesla’s profitability?
# 12. What are Tesla’s major production locations and properties?
# 13. How does Tesla address cost reduction strategies?
# 14. What operational challenges arise from global expansion?
# 15. How does Tesla manage dependence on raw materials?
# 16. What do Tesla’s MD&A trends indicate about future financial risk?
# 17. What environmental regulations impact Tesla’s operations?
# 18. What risks stem from Tesla’s autonomous driving development?
# 19. How does Tesla manage its workforce across global regions?
# 20. What microeconomic factors affect Tesla’s EV sales?
# 21. How does Tesla evaluate foreign jurisdiction risks in inspections?
# 22. What are Tesla’s major risk factor categories in Item 1A?
# 23. What market risks does Tesla face from competition in batteries?
# 24. What litigation risks relate to safety, environment, or labor?
# 25. How does Tesla see growth opportunities internationally?
# 26. What risks arise from reliance on government incentives?
# 27. What risks does Tesla see with scaling energy generation products?
# 28. How does Tesla assess customer demand variations?
# 29. What financing risks does Tesla report?
# 30. What major changes occurred in Tesla’s 2023 reporting year?
#
# ---
#
# # ✅ **30 Questions for BlackRock, Inc.**
#
# (based on BlackRock content in your PDF)
#
# 1. What types of equity securities does BlackRock hold?
# 2. How does BlackRock measure fair value for non-marketable investments?
# 3. What risks arise from early-stage private company investments?
# 4. What is the value of BlackRock’s marketable equity securities in 2024?
# 5. How does BlackRock hedge market price risk on equity investments?
# 6. What are BlackRock’s equity method investment values?
# 7. What are the major components of BlackRock-defined contribution plans by region?
# 8. How much revenue does BlackRock earn from related-party advisory services?
# 9. What are BlackRock’s receivables from investment funds?
# 10. What regulatory capital restrictions affect BlackRock subsidiaries?
# 11. What major compensation and incentive plans are disclosed in exhibits?
# 12. What is BlackRock’s Global Insider Trading Policy? (exhibit 19)
# 13. How does BlackRock structure long-term incentive compensation?
# 14. What role do advisory fees play in BlackRock’s revenue mix?
# 15. What is the firm’s approach to international tax exposure?
# 16. How does BlackRock assess impairment in equity-method investments?
# 17. What liquidity risks arise from private market funds?
# 18. How does BlackRock evaluate its subsidiaries and guarantor entities?
# 19. What major lease agreements does BlackRock disclose?
# 20. What are the key revenue components for advisory performance fees?
# 21. What changes were made in the leadership retention carry plan?
# 22. How does BlackRock describe risk related to global markets volatility?
# 23. What is BlackRock’s pension obligation status?
# 24. How does the firm manage cross-border capital requirements?
# 25. What are BlackRock’s main sources of non-operating income?
# 26. What are the key risks tied to ETFs and mutual fund flows?
# 27. How do market cycles impact BlackRock’s assets under management?
# 28. What compensation recovery (clawback) policy is disclosed?
# 29. What new amendments to financing agreements occurred in 2023–24?
# 30. What is the structure of BlackRock's commercial paper program?
